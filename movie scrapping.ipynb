# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
from time import sleep
from random import randint
import numpy as np

headers = dict()
headers[
    "User-Agent"
] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36"

titles = []
years = []
time = []
imdb_ratings = []
genre = []
votes = []
pages = np.arange(1, 1001, 50)
for page in pages:
    url = "https://www.imdb.com/search/title/?groups=top_1000&start=" + str(page)
    results = requests.get(url, headers=headers)
    soup = BeautifulSoup(results.text, "html.parser")
    movie_div = soup.find_all("div", class_="lister-item mode-advanced")
    sleep(randint(2, 10))
    print(page)
    for movieSection in movie_div:
        name = movieSection.h3.a.text
        titles.append(name)
        year = movieSection.h3.find("span", class_="lister-item-year").text
        years.append(year)
        ratings = movieSection.strong.text
        imdb_ratings.append(ratings)
        category = movieSection.find("span", class_="genre").text.strip()
        genre.append(category)
        runTime = movieSection.find("span", class_="runtime").text
        time.append(runTime)
        nv = movieSection.find_all("span", attrs={"name": "nv"})
        vote = nv[0].text
        votes.append(vote)
movies = pd.DataFrame(
    {
        "Movie": titles,
        "Year": years,
        "RunTime": time,
        "imdb": imdb_ratings,
        "Genre": genre,
        "votes": votes,
    }
)

# cleaning
movies["Year"] = movies["Year"].str.extract("(\\d+)").astype(int)
movies["RunTime"] = movies["RunTime"].str.replace("min", "minutes")
movies["votes"] = movies["votes"].str.replace(",", "").astype(int)

print(movies)
movies.to_csv(r"movies scrap.csv", index=False, header=True)
# Out:
# 1
# 51
# 101
# 151
# 201
# 251
# 301
# 351
# 401
# 451
# 501
# 551
# 601
# 651
# 701
# 751
# 801
# 851
# 901
# 951
#                              Movie  Year      RunTime imdb  \
# 0            A Quiet Place Part II  2020   97 minutes  7.8
# 1     Zack Snyder's Justice League  2021  242 minutes  8.1
# 2    The Mitchells vs the Machines  2021  113 minutes  7.8
# 3                Avengers: Endgame  2019  181 minutes  8.4
# 4                       The Father  2020   97 minutes  8.3
# ..                             ...   ...          ...  ...
# 995           Lage Raho Munna Bhai  2006  144 minutes  8.0
# 996                     The Circus  1928   72 minutes  8.1
# 997          Auf der anderen Seite  2007  122 minutes  7.8
# 998          Nefes: Vatan Sagolsun  2009  128 minutes  8.0
# 999                          Anand  1971  122 minutes  8.3
#
#                             Genre   votes
# 0           Drama, Horror, Sci-Fi   32800
# 1      Action, Adventure, Fantasy  302681
# 2    Animation, Adventure, Comedy   58771
# 3        Action, Adventure, Drama  888023
# 4                           Drama   70559
# ..                            ...     ...
# 995        Comedy, Drama, Romance   44102
# 996               Comedy, Romance   31068
# 997                         Drama   31145
# 998       Action, Drama, Thriller   32373
# 999                Drama, Musical   31940
#
# [1000 rows x 6 columns]
