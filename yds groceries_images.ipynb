# %%
import requests
from requests import get
#from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time 
from random import randint
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
import base64
from PIL import Image
from io import BytesIO
from urllib.request import urlopen
from binascii import a2b_base64
import urllib, io
import urllib.request

# %%
headers = {"Accept-Language": "en-US, en;q=0.5"}
opts = Options()
opts.headless = False
driver = webdriver.Chrome(ChromeDriverManager().install(),options=opts)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\yfird\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
page=1
while page!=10:
    url="https://ydsgroceries.com/fresh-food.html?p={}".format(page)
    attempt = 1
    max_attempts=3
    try:
        driver.get(url)
    except TimeoutException as ex:
        print(ex.Message)
        driver.navigate().refresh()
     
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")#scrolls through page to ensure pge loads before scraping
    time.sleep(20)
    try:  
        products= WebDriverWait(driver,30).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR,"div.product-item-info.type4")))
        WebDriverWait(driver,20)
        for p in products:
            if p is not None:
                file_name=p.find_element_by_tag_name('strong').text.replace('/','-').strip()
               # specialChars = '!#"$:[]$@%^&*()'
                #for specialChar in specialChars:
                    #file_name=file_name.replace(specialChar, '')
            else:
                file_name=None
            print (file_name)
            if p is not None:
                img = p.find_element_by_tag_name("img")
                img_src= img.get_attribute("src")
            else:
                img_src=None
            print(img_src)
            #im = Image.open(io.BytesIO(base64.b64decode(img_src.split(',')[1])))
            #im.save(file_name + '.jpg')
            #im=img_src
            #if im.mode == "JPEG":
                #im.save(file_name + '.jpg')
                # in most case, resulting jpg file is resized small one
            #elif im.mode in ["RGBA", "P"]:
                #rgb_im = im.convert("RGB")
                #rgb_im.save(file_name + '.jpg')//
            #urllib.request.urlretrieve(img_src, file_name + '.png')
    except StaleElementReferenceException:
        if attempt == max_attempts:
                raise
        attempt += 1
 
    #base64_string =img_src # that monster you saw above
   # s=('GET ' + img_src + ' HTTP/1.0\r\n\r\n')
    #decoded_string = base64.b64decode(s)
   # decoded_string.save('file_name', 'JPEG')
    page=page+1
# Out:
# Bag of Potatoes
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/f/u/full-bag-selected-irish-potatoes-selar.co-5e5e9321a7a23.jpg
# Organic chicken sausage- 32 pieces
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/i/m/img_4642.jpg
# Organic Chicken breast- 1kg
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/i/m/img_4637.jpg
# Organic Broiler wings- 1kg
# ...- 1kg
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Organic Local chicken
# ...(Small)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/a/l/alphonso-mango-stock-image-1-1024x686_1.jpg
# Mango (Large)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/r/i/ripe-mango-gettyimages-535252402-58c878775f9b58af5c5b23c7_2.jpg
# Shambo
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/c/o/corqaa.jpg
# Coconut (1 Piece)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/c/o/coconuts-1280x720.jpg
# Kpomo (1 Piece)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/k/p/kpomo-wele_1.jpg
# Smoked Titus Fish (1 Piece)
# ...(Portion)
# ...(3 pieces)
# ...- Portion
# ...- Portion
# ...- Portion
# ...- small
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/r/e/redcabbage.jpg
# Fresh Ginger- Portion
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/g/i/ginger-1191302.jpg
# Sorrel Yakuwa Leaves- Bunch
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/s/o/sorrel-yakuwa-leaves.jpg
# Lamb Ribs Whole
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Beetroot - ! Piece
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Grapes
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Unripe Plantain
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/i/t/itd9lxna.jpeg
# Beef Diced - 1kg
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/o/x/oxgfejma.png
# Garden-Egg Leaves Bunch
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/y/s/ysenlzaa.jpeg
# Water-leaf Bunch
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Smoked Catfish Portion
# ...- 1 Piece
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Local Chicken- Medium
# ...- 1 head
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/f/r/fresh-broccoli-500x500.jpg
# Cauliflower- 1 head
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/p/7/p7_cauliflower_hh1810_gi887543438.jpg
# Spinach-Bunch
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/s/p/spinach-explosives-countries.jpg
# Celery- Bunch
# ...- Aubergines (1 Piece)
# ...-3 bottles
# ...-3-large
# ...-5-small
# ...-avocado
# ...-basket
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/i/m/images_5_.jpeg
# large-size-banana
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/1/_/1_-c2f1g.jpeg
# English-pear
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/i/s/istockphoto-615641140-612x612.jpg
# Large-size-watermelon
# ...-size-watermelon
# ...-size-banana-bunch
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# pineapple
# ...- Portion (1KG +)
# ...://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/c/a/cabbage-2_1.jpg
# Cow Leg-Portion (1KG)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/c/o/cow-leg.jpg
# Sardine Fish- 1KG
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/s/a/sardine-copy.jpg
# Croaker Fish-1KG
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Lamb chops- 1KG
# ...- 1KG
# ...- Portion
# ...(pumpkin leaves)-Sliced Bunch
# ...(Nigerian Spinach)- Bunch
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/n/i/nigerian-spinach.png
# Spring onions (Bunch)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/2/9/297.png
# Fresh Lime (portion)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/c/i/citrus_limes_hero.jpg
# Peas- Small portion
# ...(Portion)
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Cucumber (Large)
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
# Sweet Potatoes
# ...://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/i/r/irish-potatoes-obumoonde_1.jpg
# Fresh Onions
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/o/n/onions-2405523.jpeg
# Fresh Red Bell pepper (Tetashe)
# https://ydsgroceries.com/pub/media/catalog/product/cache/c3c9ebabe813ddbdb1e561b2a421fd99/6/2/624-2.jpg
# Fresh Scotch bonnet
# ...:image/gif;base64,R0lGODlhAQABAIAAAPT09P///yH5BAEAAAEALAAAAAABAAEAAAICRAEAOw==
