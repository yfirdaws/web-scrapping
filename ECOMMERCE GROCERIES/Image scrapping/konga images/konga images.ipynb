# %%
import requests
from requests import get
#from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
#from selenium.webdriver.common.keys import Keys
#from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
#from urllib.request import urlopen
from selenium.common.exceptions import StaleElementReferenceException

# %%
headers = {"Accept-Language": "en-US, en;q=0.5"}
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\yfird\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
page=1
while page!=40:
    url=f"https://www.konga.com/category/groceries-581?page={page}"
    attempt = 1
    max_attempts=3
    try:
        driver.get(url)
        #driver.find_element_by_tag_name('html').send_keys(Keys.END)
    except TimeoutException as ex:
        print(ex.Message)
        driver.navigate().refresh()

    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")#scrolls through page to ensure pge loads before scraping
    WebDriverWait(driver,5)
    try:  
        products= WebDriverWait(driver,30).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR,"img.f5e10_VzEXF._59c59_3-MyH.lazyloaded")))
        for p in products:
            if p is not None:
                file_name=p.get_attribute('alt').replace("-"," ")
                file_name=file_name.replace("/"," ")
                file_name=file_name.replace(",",'')
            else:
                file_name=None
            print (file_name)
            if p is not None:
                img_src=p.get_attribute('src')
            else:
                img_src=None
            print(img_src)
            response = requests.get(img_src)
            file = open(f'{file_name}.jpg', "wb")
            file.write(response.content)
            file.close()
    except StaleElementReferenceException:
        if attempt == max_attempts:
                raise
        attempt += 1
    page=page+1
# Out:
# Peper Tomatoes X 50 Sacket.
# https://www-konga-com-res.cloudinary.com/w_auto,f_auto,fl_lossy,dpr_auto,q_auto/media/catalog/product/S/I/134948_1603049576.jpg
# Garlic Powder   100g x 3.
# https://www-konga-com-res.cloudinary.com/w_auto,f_auto,fl_lossy,dpr_auto,q_auto/media/catalog/product/R/S/63450_1601661395.jpg
# Pink Salt   Enriched W  84+mineralsmedium Grind 2 3mm 16oz.
# https://www-konga-com-res.cloudinary.com/w_auto,f_auto,fl_lossy,dpr_auto,q_auto/media/catalog/product/Z/W/142592_1601976915.jpg
# Freshjax Gourmet Thai Coconut Curry Yellow Red And Green 6.5 Oz.
# https://www-konga-com-res.cloudinary.com/w_auto,f_auto,fl_lossy,dpr_auto,q_auto/media/catalog/product/Y/R/142592_1598601026.jpg
# Mccormick Whole Black Peppercorns Organic Non gmo Kosher 14.7 Oz.
# https://www-konga-com-res.cloudinary.com/w_auto,f_auto,fl_lossy,dpr_auto,q_auto/media/catalog/product/E/L/142592_1596733973.jpg
# Blended Sesame Oil.
# ...
