# %%
import requests
from requests import get
#from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from urllib.request import urlopen
from selenium.common.exceptions import StaleElementReferenceException

# %%
headers = {"Accept-Language": "en-US, en;q=0.5"}
opts = Options()
opts.headless = False
driver = webdriver.Chrome(ChromeDriverManager().install(),options=opts)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Get LATEST driver version for 91.0.4472
# Trying to download new driver from https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\yfird\.wdm\drivers\chromedriver\win32\91.0.4472.101]

# %%
page=1
while page!=5:
    urls=["https://mart.ng/fruits-vegetables.html?p={}".format(page),"https://mart.ng/drinks-beverages.html?p={}".format(page),"https://mart.ng/food-cupboard.html?p={}".format(page)]
    for url in urls:
        attempt = 1
        max_attempts=3
        try:
            driver.get(url)
            #driver.find_element_by_tag_name('html').send_keys(Keys.END)
        except TimeoutException as ex:
            print(ex.Message)
            driver.navigate().refresh()

        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")#scrolls through page to ensure pge loads before scraping
        WebDriverWait(driver,5)
        try:  
            products= WebDriverWait(driver,20).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR,"img.product-image-photo.default_image")))
            for p in products:
                if p is not None:
                    file_name=p.get_attribute('alt')
                else:
                    file_name=None
                print (file_name)
                if p is not None:
                    img_src=p.get_attribute('src')
                else:
                    img_src=None
                print(img_src)
                response = requests.get(img_src)
                file = open(f'{file_name}.jpg', "wb")
                file.write(response.content)
                file.close()
        except StaleElementReferenceException:
            if attempt == max_attempts:
                    raise
            attempt += 1
        page=page+1
# Out:
# Water Leaves
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/w/a/water_leaf.jpg
# Onions - Basket
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/o/n/onions_basket.jpg
# Irish Potatoes - 14 Pieces
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/i/r/irish_potatoes.jpg
# Turmeric - 150g
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/t/u/turmeric.jpg
# Garlic - 8 Bulbs
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/g/a/garlic.jpg
# Lime - Bottled
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/l/i/lime_bottled.jpg
# Garlic Powder - Bottled
# https://mart.ng/pub/media/catalog/product/cache/1700cc3c5c99f9918946804ee33fba1b/g/a/garlic_powder_-_bottled.jpg
# Ginger Powder - Bottled
# ...
